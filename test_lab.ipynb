# %%
from matplotlib import pyplot as plt
import numpy as np
# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()
# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import create_a_py_file
# Out:
# ['C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\Resources\\ArcPy', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python311.zip', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3', '', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\Babel-2.11.0-py3.11.egg', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\future-0.18.3-py3.11.egg', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\pytz-2022.6-py3.11.egg', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\pywin32security', 'C:\\Users\\35196\\AppData\\Local\\Programs\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\sympy-1.12-py3.11.egg']
#
# Please wait a moment while I gather a list of all available modules...
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\mapping\_msl\layer.py:1772: DeprecatedWarning: _MSILayerFactory is deprecated as of 2.4.0 and has been removed in 2.4.2. Use the _MSILayerFactory class found in `arcgis.layers._MSILayerFactory` instead.
#   class MapServiceLayer(Layer, metaclass=_MSILayerFactory):
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\mapping\_scenelyrs\_lyrs.py:1530: DeprecatedWarning: _SceneLayerFactory is deprecated as of 2.4.0 and has been removed in 2.4.2. Use the _SceneLayerFactory class found in `arcgis.layers._SceneLayerFactory` instead.
#   class SceneLayer(Layer, metaclass=_SceneLayerFactory):
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pytz-2022.6-py3.11.egg\pytz\__init__.py:102: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pkg_resources\__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pkg_resources\__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pkg_resources\__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\traitlets\traitlets.py:3913: DeprecationWarning: Keyword `trait` is deprecated in traitlets 5.0, use `value_trait` instead
#   warn(
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\traitlets\traitlets.py:3615: DeprecationWarning: Traits should be given as instances, not types (for example, `Int()`, not `Int`). Passing types is deprecated in traitlets 4.1.
#   super().__init__(trait=trait, default_value=default_value, **kwargs)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\jupyter_lsp\handlers.py:6: DeprecationWarning: jupyter_server.base.zmqhandlers module is deprecated in Jupyter Server 2.0
#   from jupyter_server.base.zmqhandlers import WebSocketHandler, WebSocketMixin
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\pkgutil.py:92: DeprecationWarning: Terminals support has moved to `jupyter_server_terminals`
#   __import__(info.name)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\nbconvert\filters\strings.py:23: DeprecationWarning: Support for bleach <5 will be removed in a future version of nbconvert
#   from nbconvert.preprocessors.sanitize import _get_default_css_sanitizer
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 16 from C header, got 96 from PyObject
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\nose\config.py:142: DeprecationWarning: invalid escape sequence '\.'
#   """nose configuration.
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\nose\importer.py:12: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   from imp import find_module, load_module, acquire_lock, release_lock
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\pkgutil.py:92: DeprecationWarning:
#
#   `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#   of the deprecation of `distutils` itself. It will be removed for
#   Python >= 3.12. For older Python versions it will remain present.
#   It is recommended to use `setuptools < 60.0` for those Python versions.
#   For more details, see:
#     https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#   __import__(info.name)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\_distutils_hack\__init__.py:31: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\pkgutil.py:92: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__(info.name)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pip\_vendor\pkg_resources\__init__.py:2871: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pip\_vendor\pkg_resources\__init__.py:2871: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pip\_vendor\pkg_resources\__init__.py:2871: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\saspy\sasproccommons.py:389: DeprecationWarning: invalid escape sequence '\:'
#   if len([word for word in tgt if any(letter in word for letter in '/\:;.%')]) != 0:
# <frozen importlib._bootstrap>:1047: ImportWarning: BackendFinder.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:673: ImportWarning: BackendLoader.exec_module() not found; falling back to load_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: BackendFinder.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: BackendFinder.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: BackendFinder.find_spec() not found; falling back to find_module()
# C:\Users\35196\AppData\Local\Programs\ArcGIS\Pro\Resources\ArcToolbox\Scripts\ga_spark\sql\functions.py:1361: DeprecationWarning: invalid escape sequence '\*'
#   """
# <frozen importlib._bootstrap>:1047: ImportWarning: BackendFinder.find_spec() not found; falling back to find_module()
# AddGeometryAttributes _cffi_backend       fastjsonschema      optimalregionconnections
# AddItemsToCatalogDataset _codecs             faulthandler        optparse
# AddPortalItemsToCatalogDataset _codecs_cn          features_to_gtfs_shapes ordlookup
# AddVehicleRoutingProblemBreaks _codecs_hk          features_to_gtfs_stops os
# AddVehicleRoutingProblemRoutes _codecs_iso2022     featuretoraster     osgeo
# AggregatePointsCore _codecs_jp          filecmp             osgeo_utils
# BatchDefineSR       _codecs_kr          fileinput           overlaylayers_sa
# BatchProject        _codecs_tw          fill                overrides
# BatchPyramids       _collections        flake8              packaging
# BatchStats          _collections_abc    flowaccumulation    pandas
# BivariateDependence _compat_pickle      flowdirection       pandocfilters
# CalculateAreas      _compression        flowdistance        parso
# CalculateDensity_standard _contextvars        fnmatch             partd
# CalculateDistanceBand _csv                fontTools           past
# CalculateEndDate    _ctypes             fractions           pathlib
# CalculateKernelDensityRatio _ctypes_test        fsspec              pathspec
# CalculateTransitServiceFrequency _datetime           ftplib              patsy
# CancelRemainingTasks _decimal            functools           pdb
# CatalogDatasetUtil  _distutils_hack     future              pefile
# CentralFeature      _elementtree        ga_desktop_aggregatepoints peutils
# ClassifyIndoorPathways _functools          ga_desktop_appenddata phototopoint
# CollectEvents       _hashlib            ga_desktop_calculatedensity pickle
# CompressFileGeodatabaseData _heapq              ga_desktop_calculatefield pickleshare
# ConfigureIndoorPositioning _imp                ga_desktop_calculatemotionstatistics pickletools
# ConnectNetworkDatasetTransitSourcesToStreets _io                 ga_desktop_cliplayer pip
# ConversionUtils     _json               ga_desktop_copydatasetfrombigdataconnection pipes
# CopyExtendedProperties _locale             ga_desktop_createbigdataconnectionfile pkg_resources
# CopyJobFiles        _lsprof             ga_desktop_createbuffers pkgutil
# CopyNetworkAnalysisLayer _lzma               ga_desktop_createspacetimecube platform
# CreateDriveTimeAreas_dt _markupbase         ga_desktop_describedataset platformdirs
# CreateFeaturesFromTextFile _md5                ga_desktop_detectincidents plistlib
# CreateIndoorsDatabase _msi                ga_desktop_dissolveboundaries pluggy
# CreateJobForTask    _multibytecodec     ga_desktop_duplicatedatasetfrombigdataconnection poplib
# CreateSQLiteDatabase _multiprocessing    ga_desktop_findPointClusters posixpath
# CreateTaskGroupJobs _opcode             ga_desktop_finddwelllocations pprint
# CreateUPDM          _operator           ga_desktop_findhotspots pro_notebook_integration
# DDD_Training        _osx_support        ga_desktop_findsimilarlocations profile
# DDD_Training_Classification _overlapped         ga_desktop_forestbasedclassificationandregression prometheus_client
# DEChartUtils        _pickle             ga_desktop_generalizedlinearregression prompt_toolkit
# DEFieldStatisticsToTable _py_abc             ga_desktop_groupbyproximity pstats
# DefenseUtilities    _pydecimal          ga_desktop_joinfeatures psutil
# DirToCatalog        _pyio               ga_desktop_mergelayers psygnal
# DirToGeodatabase    _pytest             ga_desktop_overlaylayers pty
# DirToMosaic         _queue              ga_desktop_previewdatasetfrombigdataconnection pure_eval
# DirToNewMosaic      _random             ga_desktop_reconstructtracks puremagic
# DirectionalMean     _server_admin       ga_desktop_refreshbigdataconnectionfile py
# ErrorUtils          _sha1               ga_desktop_removedatasetfrombdc py_compile
# ExcelAnalyze        _sha256             ga_desktop_snaptracks pyarrow
# ExcelAnalyze31      _sha3               ga_desktop_summarizeattributes pybind11
# ExcelAnalyzeServer  _sha512             ga_desktop_summarizecenteranddispersion pyclbr
# ExcelAnalyzeX       _signal             ga_desktop_summarizewithin pycodestyle
# ExcelAnalyzeX31     _sitebuiltins       ga_desktop_traceproximityevents pycparser
# ExcelDeleteFields   _socket             ga_desktop_updatebdcdatasetproperties pydantic
# ExcelToTable        _sqlite3            ga_server_aggregatepoints pydantic_core
# ExcelToTable31      _sre                ga_server_appenddata pydoc
# ExcelToTableServer  _ssl                ga_server_buildmultivariablegrid pydoc_data
# ExcelToTableX       _stat               ga_server_calculatedensity pyexpat
# ExcelToTableX31     _statistics         ga_server_calculatefield pyflakes
# ExifUtils           _string             ga_server_calculatemotionstatistics pygments
# ExploratoryRegression _strptime           ga_server_cliplayer pylab
# ExportGeneralizedData _struct             ga_server_copytodatastore pyodbc
# ExportRasters       _symtable           ga_server_createbuffers pyparsing
# ExportWebMap        _testbuffer         ga_server_createspacetimecube pypdf
# ExportXYV           _testcapi           ga_server_describedataset pytest
# ExtractData         _testconsole        ga_server_detectincidents pythonjsonlogger
# FabricForArcMapToArcGISPro _testimportmultiple ga_server_dissolveboundaries pytz
# FeatureclassConversion _testinternalcapi   ga_server_finddwelllocations pywintypes
# FeaturesToGPX       _testmultiphase     ga_server_findhotspots queue
# FeaturesToGTFSShapes _thread             ga_server_findpointclusters quopri
# FeaturesToGTFSStops _threading_local    ga_server_findsimilarlocations random
# FindClosestFacilities _tkinter            ga_server_forestbasedclassificationandregression rapathutils
# FindHotSpots_standard _tokenize           ga_server_generalizedlinearregression rastertofeatures
# FloorplansToIndoors _tracemalloc        ga_server_geographicallyweightedregression rasurfaceparameters
# GLR                 _typing             ga_server_groupbyproximity rautils
# GPXtoFeatures       _uuid               ga_server_joinfeatures re
# GTFSShapesToFeatures _warnings           ga_server_mergelayers referencing
# GTFSStopsToFeatures _weakref            ga_server_overlaylayers regex
# GTFSToNetworkDatasetTransitSources _weakrefset         ga_server_reconstructtracks reprlib
# GWR                 _win32sysloader     ga_server_snaptracks requests
# GeneralG            _winapi             ga_server_summarizeattributes requests_gssapi
# GenerateDefinitionQueryFromSelection _xxsubinterpreters  ga_server_summarizecenteranddispersion requests_kerberos
# GenerateDefinitionQueryFromSelectionUtils _yaml               ga_server_summarizewithin requests_oauthlib
# GenerateFacilityEntryways _zoneinfo           ga_server_traceproximityevents requests_toolbelt
# GenerateFloorTransitions abc                 ga_spark            rfc3339_validator
# GenerateIndoorPathways addGPSMetadataFields gapy                rfc3986_validator
# GenerateIsogonicLines aggregatepoints_standard gautils             rlcompleter
# GenerateOccupantFeatures aifc                gc                  rpds
# GenerateServiceAreas analysisutils       gdbschema           runpy
# GenerateShapesFeaturesFromGTFS annotated_types     generate_shapes_features_from_gtfs sarl
# GenerateTessellation antigravity         generatepointsfromlines saspy
# GenerateTopographicContours anyio               genericpath         sched
# GenerateTransectLines anywidget           geoanalytics        scipy
# GeoAIExtractFeaturesUtils aolutils            geoanalyticssoap    seaborn
# Geoenrichment       appdirs             geomet              secrets
# GetFeaturesByJobAOI arceditor           getopt              select
# GetLayoutTemplatesInfo arcengine           getpass             selectors
# GetReportTemplatesInfo arcenginegeodb      gettext             send2trash
# Gi                  arcgis              glob                setuptools
# IPython             arcgisscripting     graphlib            shapefile
# ImportGeneralizationData arcinfo             greenlet            shelve
# IndoorsUtilsModule  arcpy               gssapi              shlex
# InsertTaskGroup     arcpy_init          gtfs_shapes_to_features shutil
# InterpolatePoints_standard arcpy_wmx           gtfs_stops_to_features signal
# IsoClusterUnsupervised arcserver           gtfs_to_network_dataset_transit_sources site
# KFunction           arcview             gtfs_utils          six
# LeastCostCorridor   argon2              gzip                smtpd
# LocalMoran          argparse            h11                 smtplib
# MeanCenter          array               h5py                sndhdr
# MedianCenter        ast                 hashlib             sniffio
# MoransI             asttokens           heapq               socket
# MoransI_Increment   async_lru           hmac                socketserver
# MoransI_Step        asynchat            hostedgp            socks
# MultiRingBuffer     asyncio             html                sockshandler
# MultivariateClustering asyncore            http                sortedcontainers
# NAUtils             atexit              httpcore            soupsieve
# NearestNeighbor     attr                httpx               spatial_reference_helper
# NeighborhoodSummaryStatistics attrs               idlelib             splitbyattribute
# Network2SWM         audioop             idna                spnego
# NetworkSWM          autocommand         imaplib             sqlalchemy
# NewScriptTemplate   avrpb               imghdr              sqlite3
# OLS                 avrpr               imp                 sre_compile
# OptimalCorridorConnections babel               importe00           sre_constants
# OptimizedHotSpotAnalysis backports           importlib           sre_parse
# OptimizedOutlierAnalysis bapy                importlib_metadata  ssl
# PIL                 base64              importlib_resources sspi
# Partition           bdb                 indoorsdatapy       sspicon
# PointToLine         binascii            indoorsprotocol     sspilib
# ProcessRestRequest  bisect              indoorssql          stack_data
# RasterConversion    black               inflect             stat
# SABRE               blackd              iniconfig           statistics
# SAS2Table           bleach              inspect             statsmodels
# SAS_Utilities       blib2to3            intel               storagecapacity
# SKATER              blinker             interpolate         streamlink
# SSAttributeUncertainty bottleneck          io                  string
# SSBivariateAssociation brotli              ipaddress           stringprep
# SSCalSpatialExpVar  bs4                 ips                 struct
# SSCalculateRate     bufferUtils         ipykernel           subprocess
# SSCausalInferenceAnalysis builtins            ipykernel_launcher  summarizeraster
# SSClearSelection    bz2                 ipython_genutils    sunau
# SSCluster           cProfile            ipywidgets          swat
# SSColocation        cachetools          isodate             sympy
# SSCompositeIndex    calculatePluginOutput isympy              symtable
# SSConvertFieldType  calculate_transit_service_frequency itertools           sys
# SSCube              calculate_transit_service_frequency_od_config jdcal               sysconfig
# SSCubeObject        calculate_transit_service_frequency_sa_config jedi                tabnanny
# SSCubeUtilities     calculatecostpath   jinja2              tarfile
# SSDataObject        calculatecostpathpoly json                tblib
# SSDataReduction     calculatedistance   json5               telnetlib
# SSDecomposeSpatialStructure calculategeometry   jsonschema          tempfile
# SSDirectionalTrend  calculatenetwork    jsonschema_specifications terminado
# SSEncodeField       calculatetravelcost jupyter             tessellate
# SSForest            calendar            jupyter_client      testpath
# SSFuzzyKappa        certifi             jupyter_console     textwrap
# SSHelperFunctions   cffi                jupyter_core        this
# SSImpute            cftime              jupyter_events      threading
# SSLocalPolyRegr     cgi                 jupyter_lsp         time
# SSMGWR              cgitb               jupyter_server      timeit
# SSModelPredict      chardet             jupyter_server_terminals tinycss2
# SSOptimal           charset_normalizer  jupyterlab          tkinter
# SSPanel             chunk               jupyterlab_pygments tlz
# SSPanelObject       classifyobjectsusingdl jupyterlab_server   token
# SSPopupImageConvertor classifypixelsusingdl jupyterlab_widgets  tokenize
# SSPopupImageConvertor_CIA click               jwt                 toml
# SSPopupImageConvertor_CPD cloudpickle         keyring             tomli
# SSPopupImageConvertor_LBR cmath               keyword             tomllib
# SSPopupImageConvertor_TSA cmd                 kiwisolver          toolz
# SSPopupImageConvertor_TSCC code                lerc                tornado
# SSPopupImageConvertor_TSS codecs              lib2to3             tqdm
# SSPresenceOnlyPrediction codeop              libfuturize         trace
# SSRates             collections         libpasteurize       traceback
# SSReclassifyField   colorama            linecache           tracemalloc
# SSReport            colorsys            locale              traitlets
# SSReportXML         comm                locket              truststore
# SSSpatialSampling   compileall          loggerutils         tty
# SSSpatialThinning   concurrent          logging             turtle
# SSStandardizeField  configparser        lxml                turtledemo
# SSStringFormatting  connect_network_dataset_transit_sources_to_streets lz4                 typeguard
# SSSymbology         contextlib          lzma                types
# SSTSSmoothing       contextvars         mailbox             typing
# SSTimeSeries        contourpy           mailcap             typing_extensions
# SSTimeSeriesCorrelation convert_spatial_units markupsafe          ujson
# SSTimeUtilities     copy                marshal             unicodedata
# SSTransformField    copy_network_analysis_layer matchphotostorowsbytime unicodedata2
# SSUtilities         copyreg             math                unittest
# SWM2Table           create_a_py_file    matplotlib          urllib
# SendEmailWithZip    createbuffers_sa    matplotlib_inline   urllib3
# SetDataWorkspace    crypt               mccabe              uu
# SetNextTask         cryptography        mergelayers_sa      uuid
# SetProductionProperties csv                 mimetypes           venv
# SetTaskGroupDependencies ctypes              minMajority         viewshed
# SetTaskList         curses              mistune             warnings
# SetTaskStatus       cycler              mkl                 watchfiles
# ShareAsRouteLayers  cytoolz             mkl_fft             watershed
# Similarity          dask                mkl_random          wave
# StandardDistance    dataclasses         mmap                wcwidth
# StandardEllipse     dataloading         modulefinder        weakref
# Stats               datetime            more_itertools      webbrowser
# SummarizeNearby_standard dateutil            mpmath              webencodings
# SummarizeWithin_standard dbm                 msgpack             websocket
# Table2SAS           debugpy             msilib              wheel
# TableConversion     decimal             msrest              widgetsnbextension
# TableToExcel        decorator           msvcrt              win32api
# TablesToExcelServer defenseConversionToolUtilities multiprocessing     win32ctypes
# ThinIndoorPathways  defenseConversionTools mypy_extensions     win32security
# ThreeD_Utilities    defenseDistanceAndDirectionTools nat                 win32timezone
# TimeSeriesCluster   defenseDistanceAndDirectionUtilities nbclassic           win_inet_pton
# TimeSeriesUtilities defenseGRGReferenceGrid nbclient            winkerberos
# TopoWorkflowUtilities defenseGRGTools     nbconvert           winpty
# TopographicGeneralizationUtilities defenseGRGUtilities nbformat            winreg
# TrainDeepLearningModel defenseHelper       nest_asyncio        winsound
# Transpose           defenseVisibilityTools netCDF4             wrapt
# UnzipCellAndImport  defenseVisibilityUtilities netrc               wsgiref
# UpdateExtendedProperty defusedxml          networkx            xarray
# UpdatePropertyCount density             nibble              xdrlib
# UpdateTaskGroupMetrics detectobjectsusingdl nntplib             xeus_python_shell
# Weights             determinepolyline   nose                xlrd
# WeightsUtilities    difflib             notebook            xlwt
# WriteFeaturesToTextFile dis                 notebook_shim       xml
# XYTableToPoint      dissolveboundaries_sa nt                  xmlrpc
# __future__          distanceaccumulation ntpath              xxlimited
# __hello__           distanceallocation  ntsecuritycon       xxsubtype
# __phello__          distributed         nturl2path          yaml
# _abc                distutils           numbers             zict
# _aix_support        doctest             numexpr             zipapp
# _argon2_cffi_bindings email               numpy               zipfile
# _ast                encodings           oauthlib            zipimport
# _asyncio            ensurepip           odlinks             zipp
# _bisect             entrypoints         olefile             zlib
# _black_version      enum                opcode              zmq
# _blake2             errno               openpyxl            zonalstatastable
# _bootsubprocess     et_xmlfile          operator            zoneinfo
# _brotli             exceptiongroup      optimalpathasline
# _bz2                executing           optimalpathasraster
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
create_a_py_file.days_of_the_week
# Out:
# 7

# %%
create_a_py_file.say_hello
# Out:
# <function create_a_py_file.say_hello(recipient)>
